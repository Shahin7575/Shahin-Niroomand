# %%
import pandas as pd
from google.colab import drive
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

drive.mount('/content/drive')
root_path = 'drive/MyDrive/Python_Students_SuperProf/Shahin'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # loading the data

# %%
gdp_df = pd.read_csv(f'{root_path}/New_gdp.csv', index_col = 0)
npls_df = pd.read_csv(f'{root_path}/New_npls.csv', index_col = 0)

# %% [markdown]
# GDP data

# %%
gdp_df
# Out:
#     Year  GDP growth  Interest rate  Inflation rate
# 1   1993   -0.852806      10.340071        4.626735
# 2   1994    2.151024       8.152558        4.051842
# 3   1995    2.886837       7.920644        5.235423
# 4   1996    1.266785       7.952253        4.006977
# 5   1997    1.830212       7.743309        2.043108
# 6   1998    1.810615       6.094069        1.955086
# 7   1999    1.625728       4.736636        1.663460
# 8   2000    3.786955       5.138246        2.537685
# 9   2001    1.951372       4.128904        2.785165
# 10  2002    0.253943       3.158739        2.465323
# 11  2003    0.138627       2.600678        2.672556
# 12  2004    1.423594       2.762226        2.206737
# 13  2005    0.817849       3.238270        1.985293
# 14  2006    1.790640       3.424167        2.090844
# 15  2007    1.487073       3.762435        1.829741
# 16  2008   -0.962013       4.332594        3.347833
# 17  2009   -5.280937       3.027009        0.774768
# 18  2010    1.713296       3.579686        1.525516
# 19  2011    0.707333       2.944664        2.780633
# 20  2012   -2.980906       3.619199        3.041363
# 21  2013   -1.841065       3.951212        1.219993
# 22  2014   -0.004548       3.917648        0.241047
# 23  2015    0.778304       3.167866        0.038790
# 24  2016    1.293463       2.335326       -0.094017
# 25  2017    1.667859       2.258089        1.226533
# 26  2018    0.925811       1.594833        1.137488
# 27  2019    0.483198       1.648917        0.611247
# 28  2020   -8.974192       0.737515       -0.137708
# 29  2021    8.310240       0.758007        1.873783
# 30  2022    3.985897      -1.293500        8.201290
# 31  2023    0.920692      -0.361662        5.622194

# %% [markdown]
# NPLs data

# %%
npls_df
# Out:
#     Year  Capital Adequacy Ratios (CAR)  Non-Performing Loans (NPLs)  \
# 1   1993                       2.816443                     5.340071
# 2   1994                       3.479011                     4.152558
# 3   1995                       3.612424                     6.920644
# 4   1996                       3.804164                     5.952253
# 5   1997                       3.589254                     7.743309
# 6   1998                       3.838521                     8.996173
# 7   1999                       4.216443                     7.568115
# 8   2000                       4.230109                     6.777608
# 9   2001                       4.347956                     3.282581
# 10  2002                       4.485619                     4.446344
# 11  2003                       4.404376                     5.477608
# 12  2004                       4.540692                     6.126270
# 13  2005                       4.612424                     6.996173
# 14  2006                       4.604164                     6.568115
# 15  2007                       4.589254                     5.777608
# 16  2008                       4.089385                     6.282581
# 17  2009                       4.816443                     9.446344
# 18  2010                       4.979011                    10.027837
# 19  2011                       5.447956                    11.742349
# 20  2012                       5.385619                    13.746370
# 21  2013                       5.404376                    16.542706
# 22  2014                       5.880692                    18.033047
# 23  2015                       6.185530                    18.064369
# 24  2016                       5.493010                    17.116239
# 25  2017                       6.635085                    14.383299
# 26  2018                       6.333320                     8.386283
# 27  2019                       6.712812                     6.749184
# 28  2020                       6.603312                     4.359721
# 29  2021                       6.122425                     3.348097
# 30  2022                       5.890439                     2.796823
# 31  2023                       5.650000                     8.223140
#
#     Bank net interest margin (%)  Bank cost to income ratio (%)
# 1                       4.626735                       59.10000
# 2                       4.051842                       58.90000
# 3                       5.235423                       55.50000
# 4                       4.006977                       58.30000
# 5                       2.043108                       60.87000
# 6                       1.955086                       62.14000
# 7                       1.663460                       63.90000
# 8                       2.537685                       59.10000
# 9                       2.059410                       61.52906
# 10                      2.189937                       60.65203
# 11                      1.368014                       70.71611
# 12                      1.681534                       72.30321
# 13                      2.465724                       82.65440
# 14                      3.816217                       61.06435
# 15                      2.248363                       60.59713
# 16                      2.225605                       63.27329
# 17                      1.844988                       65.63255
# 18                      1.616659                       63.74392
# 19                      1.592292                       64.05728
# 20                      1.432440                       73.56432
# 21                      1.446643                       67.88760
# 22                      1.299654                       81.76258
# 23                      1.325132                       65.64462
# 24                      1.165442                       71.57465
# 25                      1.059196                       79.52383
# 26                      1.380188                       59.95825
# 27                      1.248938                       67.53194
# 28                      1.156344                       69.78554
# 29                      1.158191                       80.19948
# 30                      1.071592                       59.04476
# 31                      1.630000                       52.60000

# %% [markdown]
# # Correlation analysis

# %%
def correlation_analysis(df_1, df_2, column):
  display(pd.merge(gdp_df, npls_df[['Year',column]], on= 'Year').corr()[column])

# %%
correlation_analysis(gdp_df, npls_df, 'Capital Adequacy Ratios (CAR)')
# Out:
# Year                             0.935467
# GDP growth                      -0.135402
# Interest rate                   -0.822051
# Inflation rate                  -0.389055
# Capital Adequacy Ratios (CAR)    1.000000
# Name: Capital Adequacy Ratios (CAR), dtype: float64

# %%
correlation_analysis(gdp_df, npls_df, 'Non-Performing Loans (NPLs)')
# Out:
# Year                           0.313763
# GDP growth                    -0.193484
# Interest rate                 -0.063256
# Inflation rate                -0.497124
# Non-Performing Loans (NPLs)    1.000000
# Name: Non-Performing Loans (NPLs), dtype: float64

# %%
correlation_analysis(gdp_df, npls_df, 'Bank net interest margin (%)')
# Out:
# Year                           -0.738918
# GDP growth                      0.125125
# Interest rate                   0.772155
# Inflation rate                  0.436111
# Bank net interest margin (%)    1.000000
# Name: Bank net interest margin (%), dtype: float64

# %%
correlation_analysis(gdp_df, npls_df, 'Bank cost to income ratio (%)')
# Out:
# Year                             0.356041
# GDP growth                      -0.070540
# Interest rate                   -0.314008
# Inflation rate                  -0.532030
# Bank cost to income ratio (%)    1.000000
# Name: Bank cost to income ratio (%), dtype: float64

# %% [markdown]
# # Model training

# %% [markdown]
# Let combine the two dataframes

# %%
total_df = pd.merge(gdp_df, npls_df, on = 'Year')
total_df
# Out:
#     Year  GDP growth  Interest rate  Inflation rate  \
# 0   1993   -0.852806      10.340071        4.626735
# 1   1994    2.151024       8.152558        4.051842
# 2   1995    2.886837       7.920644        5.235423
# 3   1996    1.266785       7.952253        4.006977
# 4   1997    1.830212       7.743309        2.043108
# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# Separating the feature form the targes
X = total_df[['GDP growth', 'Interest rate', 'Inflation rate']]
y = total_df[['Capital Adequacy Ratios (CAR)', 'Non-Performing Loans (NPLs)',
              'Bank net interest margin (%)', 'Bank cost to income ratio (%)']]

# splitting the data to training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=5, random_state=0)

# to scale the data
scaler = MinMaxScaler()

# scaling the training features
X_train[['GDP growth', 'Interest rate', 'Inflation rate']] = scaler.fit_transform(X_train[['GDP growth', 'Interest rate', 'Inflation rate']])

# scaling the test features based on the paraemters of the training set
X_test[['GDP growth', 'Interest rate', 'Inflation rate']] = scaler.fit_transform(X_test[['GDP growth', 'Interest rate', 'Inflation rate']])


print('X train:', X_train.shape)
print('y train:', y_train.shape)
print('X test:', X_test.shape)
print('y test:', y_test.shape)
# Out:
# X train: (26, 3)
# y train: (26, 4)
# X test: (5, 3)
# y test: (5, 4)

# %%
def model_training(X_train, X_test, y_train, y_test, target_name):

  regression_model = LinearRegression().fit(X_train, y_train[target_name])

  # predictions of the model for the test set
  y_pred = regression_model.predict(X_test)

  print(f'Model to predict \'{target_name}\'')
  print('Mean absolute error: ', mean_absolute_error(y_test[target_name], y_pred))
  print('R2 score: ', regression_model.score(X_test, y_test[target_name]))
  print('Regression coeff: ', regression_model.coef_)

# %% [markdown]
# ## Capital Adequacy Ratios (CAR)

# %%
model_training(X_train, X_test, y_train, y_test, 'Capital Adequacy Ratios (CAR)' )
# Out:
# Model to predict 'Capital Adequacy Ratios (CAR)'
# Mean absolute error:  0.514058712332896
# R2 score:  0.7023357276927169
# Regression coeff:  [ 0.02925562 -3.33396548 -1.2108521 ]

# %% [markdown]
# ## Non-Performing Loans (NPLs)

# %%
model_training(X_train, X_test, y_train, y_test, 'Non-Performing Loans (NPLs)' )
# Out:
# Model to predict 'Non-Performing Loans (NPLs)'
# Mean absolute error:  4.79683736911165
# R2 score:  -17.548872386292395
# Regression coeff:  [-8.95423217 -1.63473851 -9.59909033]

# %% [markdown]
# ## Bank net interest margin (%)

# %%
model_training(X_train, X_test, y_train, y_test, 'Bank net interest margin (%)' )
# Out:
# Model to predict 'Bank net interest margin (%)'
# Mean absolute error:  0.9105612868863954
# R2 score:  0.6237981762183049
# Regression coeff:  [0.01928111 2.75047611 1.54111606]

# %% [markdown]
# ## Bank cost to income ratio (%)

# %%
model_training(X_train, X_test, y_train, y_test, 'Bank cost to income ratio (%)' )
# Out:
# Model to predict 'Bank cost to income ratio (%)'
# Mean absolute error:  3.9155119671604126
# R2 score:  0.4309101940564154
# Regression coeff:  [  4.24308284  -5.94122065 -15.37114664]
